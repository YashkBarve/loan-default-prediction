# %%
import pickle

# Step 1: Saving the models and encoders
# Assuming you already have the trained models and encoders
with open('rf_model.pkl', 'wb') as f:
    pickle.dump(rf, f)
with open('svm_model.pkl', 'wb') as f:
    pickle.dump(svm, f)
with open('xgb_model.pkl', 'wb') as f:
    pickle.dump(xgb, f)
with open('label_encoders.pkl', 'wb') as f:
    pickle.dump(le_dict, f)
with open('feature_columns.pkl', 'wb') as f:
    pickle.dump(list(X.columns), f)

print('✅ Models and encoders saved!')

# Step 2: Loading the models and encoders back into memory

# Load the Random Forest model
with open('rf_model.pkl', 'rb') as f:
    rf = pickle.load(f)

# Load the Support Vector Machine model
with open('svm_model.pkl', 'rb') as f:
    svm = pickle.load(f)

# Load the XGBoost model
with open('xgb_model.pkl', 'rb') as f:
    xgb = pickle.load(f)

# Load the label encoders dictionary
with open('label_encoders.pkl', 'rb') as f:
    le_dict = pickle.load(f)

# Load the feature columns
with open('feature_columns.pkl', 'rb') as f:
    feature_columns = pickle.load(f)

print('✅ Models and encoders loaded successfully!')

# Step 3: Using the loaded models

# Example usage of the loaded models
# Assuming you have some new data `X_new` for predictions

# Example: Making a prediction with the Random Forest model
rf_predictions = rf.predict(X_new)

# Example: Making a prediction with the Support Vector Machine model
svm_predictions = svm.predict(X_new)

# Example: Making a prediction with the XGBoost model
xgb_predictions = xgb.predict(X_new)

# If you need to reverse the encoding (using label_encoders)
# For example, to decode a label for a column 'Category'
decoded_category = le_dict['Category'].inverse_transform(encoded_labels)

# You can also use the feature columns if needed for preprocessing the new data
print(f"Loaded feature columns: {feature_columns}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 # Step 1: Saving the models and encoders
#       4 # Assuming you already have the trained models and encoders
#       5 with open('rf_model.pkl', 'wb') as f:
# ----> 6     pickle.dump(rf, f)
#       7 with open('svm_model.pkl', 'wb') as f:
#       8     pickle.dump(svm, f)
#
# NameError: name 'rf' is not defined
